# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from core.utils import evaluate_agent

# %%
from agents.greedy import GreedyAgent

greedy_agent = GreedyAgent()
evaluate_agent(
    greedy_agent,
    num_episodes=1000,
    seed=67,
    num_envs=16,
    max_steps=10000,
    reward_options={
        "reward_apple": 5.0,
        "reward_step": -0.01,
        "reward_loop_penalty": -0.1,
        "reward_death_wall": -20.0,
        "reward_death_self": -15.0,
        "reward_shaping_closer": 0.1,
        "reward_shaping_further": -0.1,
        "reward_complete": 100.0,
    },
)
# Out:
# Evaluating Agent:   0%|          | 0/1000 [00:00<?, ?it/s]
# Evaluating Agent: 100%|██████████| 1000/1000 [00:35<00:00, 28.19it/s]
# ============================================================
# Metric          | Average  | Max      | Std Dev
# ------------------------------------------------------------
# Rewards         | 134.66   | 393.07   | 123.54
# Apples          | 27.54    | 67.00    | 11.43
# Steps           | 513.82   | 10001.00 | 1019.24
#
# Death Distribution:
#  - self: 874 (87.4%)
#  - wall: 115 (11.5%)
#  - truncated: 11 (1.1%)
# ============================================================
# ({'avg': 134.65805000000012,
#   'max': 393.0699999999905,
#   'sd': 123.53686076510917},
#  {'avg': 27.54, 'max': 67.0, 'sd': 11.425515305665648},
#  {'avg': 513.818, 'max': 10001.0, 'sd': 1019.2395551959314},
#  {<DeathReason.WALL: 'wall'>: 115,
#   <DeathReason.SELF: 'self'>: 874,
#   <DeathReason.TRUNCATED: 'truncated'>: 11})

# %%
from agents.q_learning import QLearningAgent

q_learning_agent = QLearningAgent(seed=67)
q_learning_agent.load("../artifacts/models/q_learning_snake_best.pkl")
evaluate_agent(
    q_learning_agent,
    num_episodes=1000,
    seed=67,
    num_envs=16,
    max_steps=10000,
    reward_options={
        "reward_apple": 5.0,
        "reward_step": -0.01,
        "reward_loop_penalty": -0.1,
        "reward_death_wall": -20.0,
        "reward_death_self": -15.0,
        "reward_shaping_closer": 0.1,
        "reward_shaping_further": -0.1,
        "reward_complete": 100.0,
    },
)
# Out:
# Loaded Q-table from ../artifacts/models/q_learning_snake_best.pkl
# Evaluating Agent:   0%|          | 0/1000 [00:00<?, ?it/s]
# Evaluating Agent: 100%|██████████| 1000/1000 [00:33<00:00, 30.08it/s]
# ============================================================
# Metric          | Average  | Max      | Std Dev
# ------------------------------------------------------------
# Rewards         | 144.41   | 390.65   | 106.35
# Apples          | 28.48    | 74.00    | 11.77
# Steps           | 484.77   | 10001.00 | 764.88
#
# Death Distribution:
#  - self: 910 (91.0%)
#  - wall: 84 (8.4%)
#  - truncated: 6 (0.6%)
# ============================================================
# ({'avg': 144.40542000000016,
#   'max': 390.6499999999912,
#   'sd': 106.3511040009649},
#  {'avg': 28.477, 'max': 74.0, 'sd': 11.772402940776367},
#  {'avg': 484.773, 'max': 10001.0, 'sd': 764.8825135084473},
#  {<DeathReason.SELF: 'self'>: 910,
#   <DeathReason.WALL: 'wall'>: 84,
#   <DeathReason.TRUNCATED: 'truncated'>: 6})

# %% [markdown]
# # **Setup**

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# ---

# %% [markdown]
# # Greedy

# %%
from agents.greedy import GreedyAgent
from core.env.core import RewardOptions
from core.utils import evaluate_agent

greedy_agent = GreedyAgent()
evaluate_agent(
    greedy_agent,
    num_episodes=1000,
    num_apples=(1, 3),
    num_obstacles=(5, 12),
    seed=67,
    num_envs=16,
    max_steps=10000,
    reward_options=RewardOptions(
        eats_apple=24.0,
        penalty_step=-0.01,
        penalty_loop=-0.1,
        death_wall=-20.0,
        death_self=-20.0,
        shaping_closer=0.1,
        shaping_further=-0.1,
        complete=100.0,
    ),
)
# Out:
# Evaluating Agent: 100%|██████████| 1000/1000 [00:11<00:00, 88.75it/s]
# Evaluation Metrics
# ╭─────────┬─────────┬────────┬──────────┬──────────┬─────────╮
# │ Metric  │ Average │ Median │      Min │      Max │ Std Dev │
# ├─────────┼─────────┼────────┼──────────┼──────────┼─────────┤
# │ Rewards │  604.27 │ 598.98 │ -1020.58 │  1745.70 │  312.46 │
# │ Apples  │   25.65 │  25.00 │     0.00 │    70.00 │   11.21 │
# │ Steps   │  525.00 │ 362.50 │    11.00 │ 10002.00 │ 1184.20 │
# ╰─────────┴─────────┴────────┴──────────┴──────────┴─────────╯
# Death Distribution
# ╭───────────┬───────┬────────────╮
# │ Reason    │ Count │ Percentage │
# ├───────────┼───────┼────────────┤
# │ Self      │   785 │      78.5% │
# │ Wall      │   200 │      20.0% │
# │ Truncated │    15 │       1.5% │
# ╰───────────┴───────┴────────────╯
# ({'Average': 604.2654899999995,
#   'Median': 598.9849999999985,
#   'Min': -1020.5800000000276,
#   'Max': 1745.6999999999728,
#   'Std Dev': 312.46023265299004},
#  {'Average': 25.652,
#   'Median': 25.0,
#   'Min': 0.0,
#   'Max': 70.0,
#   'Std Dev': 11.212354614442052},
#  {'Average': 525.002,
#   'Median': 362.5,
#   'Min': 11.0,
#   'Max': 10002.0,
#   'Std Dev': 1184.2022048603014},
#  {<DeathReason.WALL: 'Wall'>: 200,
#   <DeathReason.SELF: 'Self'>: 785,
#   <DeathReason.TRUNCATED: 'Truncated'>: 15})

# %% [markdown]
# ---

# %% [markdown]
# # **Q-Learning**

# %%
from agents.q_learning import QLearningAgent

q_learning_agent = QLearningAgent(seed=67)
q_learning_agent.load("../artifacts/models/q_learning_snake.pkl")
evaluate_agent(
    q_learning_agent,
    num_episodes=1000,
    seed=67,
    num_envs=16,
    max_steps=10000,
    # reward_options={
    #     "reward_apple": 5.0,
    #     "reward_step": -0.01,
    #     "reward_loop_penalty": -0.1,
    #     "reward_death_wall": -20.0,
    #     "reward_death_self": -20.0,
    #     "reward_shaping_closer": 0.1,
    #     "reward_shaping_further": -0.1,
    #     "reward_complete": 100.0,
    # },
)
# Out:
# Loaded Q-table from ../artifacts/models/q_learning_snake.pkl
# Evaluating Agent:   0%|          | 0/1000 [00:00<?, ?it/s]
# Evaluating Agent: 100%|██████████| 1000/1000 [00:25<00:00, 39.28it/s]
# ============================================================
# Metric          | Average  | Max      | Std Dev
# ------------------------------------------------------------
# Rewards         | 113.89   | 366.62   | 103.80
# Apples          | 24.11    | 63.00    | 10.45
# Steps           | 412.54   | 10001.00 | 764.26
#
# Death Distribution:
#  - self: 897 (89.7%)
#  - wall: 97 (9.7%)
#  - truncated: 6 (0.6%)
# ============================================================
# ({'avg': 113.88743000000025,
#   'max': 366.6199999999899,
#   'sd': 103.80331278285634},
#  {'avg': 24.109, 'max': 63.0, 'sd': 10.452326009075684},
#  {'avg': 412.544, 'max': 10001.0, 'sd': 764.2587428770443},
#  {<DeathReason.WALL: 'wall'>: 97,
#   <DeathReason.SELF: 'self'>: 897,
#   <DeathReason.TRUNCATED: 'truncated'>: 6})

# %% [markdown]
# ---

# %% [markdown]
# # **Agent-Critic**

# %%
from agents.actor_critic import ActorCriticAgent
from core.env.core import RewardOptions
from core.utils import evaluate_agent

ac_agent = ActorCriticAgent(state_dim=11, action_dim=3, seed=67)

ac_agent.load("../artifacts/best_actor_critic.pth")

print("Evaluating Actor-Critic Agent...")
evaluate_agent(
    ac_agent,
    num_episodes=1000,
    num_apples=(1, 3),
    num_obstacles=(5, 12),
    seed=67,
    num_envs=16,
    max_steps=10000,
    reward_options=RewardOptions(
        eats_apple=24.0,
        penalty_step=-0.01,
        penalty_loop=-0.1,
        death_wall=-20.0,
        death_self=-20.0,
        shaping_closer=0.1,
        shaping_further=-0.1,
        complete=100.0,
    ),
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from agents.actor_critic import ActorCriticAgent
#       2 from core.env.core import RewardOptions
#       3 from core.utils import evaluate_agent
#       4
#
# ImportError: cannot import name 'ActorCriticAgent' from 'agents.actor_critic' (unknown location)

# %% [markdown]
# ---

# %% [markdown]
# # **Setup**

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# ---

# %% [markdown]
# # Greedy

# %%
from agents.bfs.bfs import BFSAgent
from agents.greedy import GreedyAgent
from core.env.core import RewardOptions
from core.env.types import RenderMode
from core.utils import evaluate_agent

greedy_agent = GreedyAgent()
bfs_agent = BFSAgent(42)
evaluate_agent(
    bfs_agent,
    num_episodes=3,
    width=2,
    height=2,
    num_apples=1,
    num_obstacles=0,
    seed=67,
    num_envs=16,
    max_steps=10,
    render_mode=RenderMode.HUMAN,
    reward_options=RewardOptions(
        eats_apple=24.0,
        penalty_step=-0.01,
        penalty_loop=-0.1,
        death_wall=-20.0,
        death_self=-20.0,
        shaping_closer=0.1,
        shaping_further=-0.1,
        complete=100.0,
    ),
)
# Out:
# Rendering enabled. Single environment will be run at a time.
# /home/enderpalm/cedt/snake-rl/.venv/lib/python3.13/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode 1/3 - Reward: 148.09, Steps: 3, Apples: 2, Death: Complete
# Episode 2/3 - Reward: 148.09, Steps: 4, Apples: 2, Death: Complete
# Episode 3/3 - Reward: 148.00, Steps: 3, Apples: 2, Death: Complete
# Evaluation Metrics
# ╭─────────┬─────────┬────────┬────────┬────────┬─────────╮
# │ Metric  │ Average │ Median │    Min │    Max │ Std Dev │
# ├─────────┼─────────┼────────┼────────┼────────┼─────────┤
# │ Rewards │  148.06 │ 148.09 │ 148.00 │ 148.09 │    0.04 │
# │ Apples  │    2.00 │   2.00 │   2.00 │   2.00 │    0.00 │
# │ Steps   │    3.33 │   3.00 │   3.00 │   4.00 │    0.47 │
# ╰─────────┴─────────┴────────┴────────┴────────┴─────────╯
# Death Distribution
# ╭──────────┬───────┬────────────╮
# │ Reason   │ Count │ Percentage │
# ├──────────┼───────┼────────────┤
# │ Complete │     3 │     100.0% │
# ╰──────────┴───────┴────────────╯
# BFSAgent decisions (n=10): BFS 0.0% | greedy 80.0% | other 20.0%
# ({'Average': 148.06,
#   'Median': 148.09,
#   'Min': 148.0,
#   'Max': 148.09,
#   'Std Dev': 0.04242640687119446},
#  {'Average': 2.0, 'Median': 2.0, 'Min': 2.0, 'Max': 2.0, 'Std Dev': 0.0},
#  {'Average': 3.3333333333333335,
#   'Median': 3.0,
#   'Min': 3.0,
#   'Max': 4.0,
#   'Std Dev': 0.4714045207910317},
#  {<DeathReason.COMPLETE: 'Complete'>: 3})

# %% [markdown]
# ---

# %% [markdown]
# # **Q-Learning**

# %%
from agents.q_learning import QLearningAgent

q_learning_agent = QLearningAgent(seed=67)
q_learning_agent.load("../artifacts/models/q_learning_snake.pkl")
evaluate_agent(
    q_learning_agent,
    num_episodes=1000,
    seed=67,
    num_envs=16,
    max_steps=10000,
    # reward_options={
    #     "reward_apple": 5.0,
    #     "reward_step": -0.01,
    #     "reward_loop_penalty": -0.1,
    #     "reward_death_wall": -20.0,
    #     "reward_death_self": -20.0,
    #     "reward_shaping_closer": 0.1,
    #     "reward_shaping_further": -0.1,
    #     "reward_complete": 100.0,
    # },
)
# Out:
# Loaded Q-table from ../artifacts/models/q_learning_snake.pkl
# Evaluating Agent:   0%|          | 0/1000 [00:00<?, ?it/s]
# Evaluating Agent: 100%|██████████| 1000/1000 [00:25<00:00, 39.28it/s]
# ============================================================
# Metric          | Average  | Max      | Std Dev
# ------------------------------------------------------------
# Rewards         | 113.89   | 366.62   | 103.80
# Apples          | 24.11    | 63.00    | 10.45
# Steps           | 412.54   | 10001.00 | 764.26
#
# Death Distribution:
#  - self: 897 (89.7%)
#  - wall: 97 (9.7%)
#  - truncated: 6 (0.6%)
# ============================================================
# ({'avg': 113.88743000000025,
#   'max': 366.6199999999899,
#   'sd': 103.80331278285634},
#  {'avg': 24.109, 'max': 63.0, 'sd': 10.452326009075684},
#  {'avg': 412.544, 'max': 10001.0, 'sd': 764.2587428770443},
#  {<DeathReason.WALL: 'wall'>: 97,
#   <DeathReason.SELF: 'self'>: 897,
#   <DeathReason.TRUNCATED: 'truncated'>: 6})

# %% [markdown]
# ---
